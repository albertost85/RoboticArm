# %%
import gym
import rlbench.gym
from stable_baselines3 import A2C
from stable_baselines3.a2c.policies import MlpPolicy, CnnPolicy
from stable_baselines3.common.evaluation import evaluate_policy

# %%
loaded_model = A2C.load("reach_target-state-v0_rgb_array_A2C")

# %%
print(loaded_model)

# %%
policy = loaded_model.policy
env = loaded_model.get_env()
print(env)
print(policy)
# Out:
# None
# ActorCriticPolicy(
#   (features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (mlp_extractor): MlpExtractor(
#     (shared_net): Sequential()
#     (policy_net): Sequential(
#       (0): Linear(in_features=40, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#     (value_net): Sequential(
#       (0): Linear(in_features=40, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#   )
#   (action_net): Linear(in_features=64, out_features=8, bias=True)
#   (value_net): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
saved_policy = MlpPolicy.load("reach_target-state-v0_rgb_array_A2C_policy")
print(saved_policy)
# Out:
# ActorCriticPolicy(
#   (features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (mlp_extractor): MlpExtractor(
#     (shared_net): Sequential()
#     (policy_net): Sequential(
#       (0): Linear(in_features=40, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#     (value_net): Sequential(
#       (0): Linear(in_features=40, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#   )
#   (action_net): Linear(in_features=64, out_features=8, bias=True)
#   (value_net): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
env_name = 'reach_target-state-v0'
render_mode = 'rgb_array'
observation_mode = 'state'
policy_mode = 'MlpPolicy'
model_name = 'A2C'
env = gym.make(env_name, render_mode=render_mode, observation_mode=observation_mode)
name_model = env_name + '_' + render_mode + '_' + model_name
print(name_model)
# Out:
# reach_target-state-v0_rgb_array_A2C

# %%
obs = env.reset()
action, _states = loaded_model.predict(obs)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-92e5fd35b786> in <module>
# ----> 1 obs = env.reset()
#       2 action, _states = loaded_model.predict(obs)
#
# AttributeError: 'NoneType' object has no attribute 'reset'

# %%
print(env)
# Out:
# <RLBenchEnv<reach_target-state-v0>>

# %%
model = A2C.load(name_model, env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
obs = env.reset()

# %%
action, _states = model.predict(obs)
obs, reward, done, info = env.step(action)

# %%
from matplotlib import pyplot as plt
img = env.render(mode=render_mode)

fig = plt.figure()
data = img
# Out:
# 1

# %%
step = 0
done = False
obs = env.reset()
episode_rewards = [0.0]
img = env.render(mode=render_mode)
fig = plt.figure()
im = plt.imshow(img)
plt.show()

while not done and step < 100000:
    step += 1
    action, _states = model.predict(obs)
    obs, reward, done, info = env.step(action)
    episode_rewards[-1] += reward
    if done:
        episode_rewards.append(0.0)
        print("Is done, is done! in {} steps".format(step))
    if(step%100 == 0):
        #img = env.render(mode=render_mode)
        #im = plt.imshow(img)
        #plt.show()
        print("Stage: {}".format(step))
# Out:
# Stage: 100
# Stage: 200
# Stage: 300
# Stage: 400
# Stage: 500
# Stage: 600
# Stage: 700
# Stage: 800
# Stage: 900
# Stage: 1000
# Stage: 1100
# Stage: 1200
# Stage: 1300
# Stage: 1400
# Stage: 1500
# Stage: 1600
# Stage: 1700
# Stage: 1800
# Stage: 1900
# Stage: 2000
# Stage: 2100
# Stage: 2200
# Stage: 2300
# Stage: 2400
# Stage: 2500
# Stage: 2600
# Stage: 2700
# Stage: 2800
# Stage: 2900
# Stage: 3000
# Stage: 3100
# Stage: 3200
# Stage: 3300
# Stage: 3400
# Stage: 3500
# Stage: 3600
# Stage: 3700
# Stage: 3800
# Stage: 3900
# Stage: 4000
# Stage: 4100
# Stage: 4200
# Stage: 4300
# Stage: 4400
# Stage: 4500
# Stage: 4600
# Stage: 4700
# Stage: 4800
# Stage: 4900
# Stage: 5000
# Stage: 5100
# Stage: 5200
# Stage: 5300
# Stage: 5400
# Stage: 5500
# Stage: 5600
# Stage: 5700
# Stage: 5800
# Stage: 5900
# Stage: 6000
# Stage: 6100
# Stage: 6200
# Stage: 6300
# Stage: 6400
# Stage: 6500
# Stage: 6600
# Stage: 6700
# Stage: 6800
# Stage: 6900
# Stage: 7000
# Stage: 7100
# Stage: 7200
# ...
